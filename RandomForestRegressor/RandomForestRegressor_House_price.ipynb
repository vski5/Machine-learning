# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
iowa_file_path = '/home/ubuntu/anaconda/date/home-data-for-ml-course/train.csv'

home_data = pd.read_csv(iowa_file_path)

y = home_data.SalePrice

features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[features]


train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %%
iowa_model = DecisionTreeRegressor(random_state=1)

iowa_model.fit(train_X, train_y)


val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("不指定max_leaf_nodes时的验证MAE: {:,.0f}".format(val_mae))

# 使用max_leaf_nodes的最佳值
iowa_model = DecisionTreeRegressor(max_leaf_nodes=100, random_state=1)
iowa_model.fit(train_X, train_y)
val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("使用max_leaf_nodes的最佳值: {:,.0f}".format(val_mae))
# Out:
# 不指定max_leaf_nodes时的验证MAE: 29,653
# 使用max_leaf_nodes的最佳值: 27,283

# %% [markdown]
# Random Forest:RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# 设置模型的一些初始值，random_state=1
rf_model = RandomForestRegressor(random_state=1)

# 训练模型
rf_model.fit(train_X, train_y)
#用训练好的模型预测结果
val_predictions = rf_model.predict(val_X)

# 算 预测值 和 实际值 的 平均方差
rf_val_mae = mean_absolute_error(val_predictions, val_y)

print("预测值 和 实际值 的 平均方差: {}".format(rf_val_mae))
# Out:
# 预测值 和 实际值 的 平均方差: 21857.15912981083
